# %% [markdown]
# # The Sparks Foundation
#
# ## Data Science and Business Analytics (Task-4)
#
# ### Exploratory Data Analysis - Terrorism
#
# ● Perform ‘Exploratory Data Analysis’ on dataset ‘Global Terrorism’
#
# ● As a security/defense analyst, try to find out the hot zone of terrorism.
#
# ● What all security issues and insights you can derive by EDA?
#
#
# ● Dataset: https://bit.ly/2TK5Xn5

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('GlobalTerrorism.csv',encoding='latin1')

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %% [markdown]
# ### No of Columns

# %%
len(df.columns)
# Out:
# 135

# %%
list(df.columns)
# Out:
# ['eventid',
#  'iyear',
#  'imonth',
#  'iday',
#  'approxdate',
#  'extended',
#  'resolution',
#  'country',
#  'country_txt',
#  'region',
#  'region_txt',
#  'provstate',
#  'city',
#  'latitude',
#  'longitude',
#  'specificity',
#  'vicinity',
#  'location',
#  'summary',
#  'crit1',
#  'crit2',
#  'crit3',
#  'doubtterr',
#  'alternative',
#  'alternative_txt',
#  'multiple',
#  'success',
#  'suicide',
#  'attacktype1',
#  'attacktype1_txt',
#  'attacktype2',
#  'attacktype2_txt',
#  'attacktype3',
#  'attacktype3_txt',
#  'targtype1',
#  'targtype1_txt',
#  'targsubtype1',
#  'targsubtype1_txt',
#  'corp1',
#  'target1',
#  'natlty1',
#  'natlty1_txt',
#  'targtype2',
#  'targtype2_txt',
#  'targsubtype2',
#  'targsubtype2_txt',
#  'corp2',
#  'target2',
#  'natlty2',
#  'natlty2_txt',
#  'targtype3',
#  'targtype3_txt',
#  'targsubtype3',
#  'targsubtype3_txt',
#  'corp3',
#  'target3',
#  'natlty3',
#  'natlty3_txt',
#  'gname',
#  'gsubname',
#  'gname2',
#  'gsubname2',
# ...

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
len(df['country'].unique())
# Out:
# 205

# %%
len(df['country_txt'].unique())
# Out:
# 205

# %% [markdown]
# #### So, country represents country_text and unique for each country.

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %% [markdown]
# # Terrorist Activities over the years

# %%
df1 = df.groupby('iyear')['eventid'].count().sort_values(ascending=False).to_frame()

df1.head()
# Out:
#        eventid
# iyear
# 2014     16903
# 2015     14965
# 2016     13587
# 2013     12036
# 2017     10900

# %%
sns.set()
plt.figure(figsize=(15,8))
sns.lineplot(df1.index,df1['eventid'])
plt.xlabel('Year')
plt.ylabel('Count of Terrorist Attacks Reported')
plt.show()

# %% [markdown]
# ## We can see there is an upward trend of Terrorist activities over the years staring from 1970 till now. It was highest in the year 2014.

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %% [markdown]
# # Terrorist Activities Country wise statistics

# %%
df2 = df.groupby('country_txt')['eventid'].count().sort_values(ascending=False).to_frame()

df2 = df2.head(20)

df2.plot(kind='barh',figsize=(20,15),legend=False)

plt.ylabel('Top 20 countries with highest amount of Terrorist Attacks')

plt.xlabel('Count')
# Out:
# Text(0.5, 0, 'Count')

# %% [markdown]
# #### Conclusion : Iraq ,Pakistan and Afganisthan are Top 3 countries with Highest number of Terrorist Attacks.

# %% [markdown]
# # Terrorist Activities Region wise statistics

# %%
df2 = df.groupby(['region_txt'])['eventid'].count().sort_values(ascending=False).to_frame()

df2.plot(kind='barh',figsize=(20,15),legend=False,colormap='Paired_r')

plt.ylabel('Top 12 regions with their regions with highest amount of Terrorist Attacks')

plt.xlabel('Count')

plt.show()

# %% [markdown]
# ### Conclusion : Middle East-North Afirca, South Asia and South-America are Top 3 regions with Highest number of Terrorist Attacks.

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df['latitude'].mode()
# Out:
# 0    33.303566
# dtype: float64

# %%
df['longitude'].mode()
# Out:
# 0    44.371773
# dtype: float64

# %%
df_lat_long = df[(df['latitude']== 33.303566) & (df['longitude']== 44.371773)]

df_lat_long.head()
# Out:
#             eventid  iyear  imonth  iday approxdate  extended resolution  \
# 4385   197612150001   1976      12    15        NaN         0        NaN
# 4402   197612240001   1976      12    24        NaN         0        NaN
# 10109  198001280004   1980       1    28        NaN         0        NaN
# 10588  198004010019   1980       4     1        NaN         0        NaN
# 11252  198006190004   1980       6    19        NaN         0        NaN
#
#        country country_txt  region  ... addnotes scite1 scite2  scite3  \
# 4385        95        Iraq      10  ...      NaN    NaN    NaN     NaN
# 4402        95        Iraq      10  ...      NaN    NaN    NaN     NaN
# 10109       95        Iraq      10  ...      NaN    NaN    NaN     NaN
# 10588       95        Iraq      10  ...      NaN    NaN    NaN     NaN
# 11252       95        Iraq      10  ...      NaN    NaN    NaN     NaN
#
#        dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# ...

# %% [markdown]
# #### Conclusion: The most frequent attacks were in Iraq  having latitude 33.303566 and longitude 44.371773 .
# #### This particular location was attacked 5 times within the year 1976-1980.

# %%
import geopandas as gpd
from shapely.geometry import Point, Polygon
crs = {'init':'epsg:4326'}

# %%
geometry = [Point(xy) for xy in zip(df['longitude'],df['latitude'])]

# %%
geometry[:10]

# %%
geo_df = gpd.GeoDataFrame(df, crs=crs, geometry=geometry)

# %%
geo_df.iloc[:,-1:].head()
# Out:
#                      geometry
# 0  POINT (-69.95116 18.45679)
# 1  POINT (-99.08662 19.37189)
# 2  POINT (120.59974 15.47860)
# 3   POINT (23.76273 37.99749)
# 4  POINT (130.39636 33.58041)

# %% [markdown]
# ## Checking the Most Frequent Type of Terrorist Attack

# %%
plt.figure(figsize=(15,8))
sns.countplot(y=geo_df['attacktype1_txt'], order = geo_df['attacktype1_txt'].value_counts().index)
plt.ylabel('Attack Type')
# Out:
# Text(0, 0.5, 'Attack Type')

# %% [markdown]
# ### Conclusion : We can see Bombing/Explosion , Armed Assault and Assassination are the most frequent type of Attack.

# %% [markdown]
# # Geo-locations of Most Frequent Type of Terrorist Attack

# %%
geo_df['attacktype1_txt'].value_counts()
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: attacktype1_txt, dtype: int64

# %%
geo_df['attacktype1_txt'].unique()
# Out:
# array(['Assassination', 'Hostage Taking (Kidnapping)',
#        'Bombing/Explosion', 'Facility/Infrastructure Attack',
#        'Armed Assault', 'Hijacking', 'Unknown', 'Unarmed Assault',
#        'Hostage Taking (Barricade Incident)'], dtype=object)

# %%
country_map= gpd.read_file('World_Countries.shp')

fig,ax = plt.subplots(figsize=(20,20))
country_map.plot(ax=ax, alpha=0.5, color='grey')

geo_df[geo_df['attacktype1_txt']=='Bombing/Explosion']['geometry'].plot(ax=ax, markersize=5,color='red',marker='o',label='Bombing/Explosion')

geo_df[geo_df['attacktype1_txt']=='Armed Assault']['geometry'].sample(n=18000,random_state=0).plot(ax=ax, markersize=5,color='blue',marker='v',label='Armed Assault')

geo_df[geo_df['attacktype1_txt']=='Hostage Taking (Kidnapping)']['geometry'].plot(ax=ax, markersize=5,color='green',marker='^',label='Hostage Taking(Kidnapping)')


plt.legend(prop={'size':20})

# %% [markdown]
# ## Checking the Most Frequent Target of Terrorist Attack

# %%
plt.figure(figsize=(15,20))
sns.countplot(y=geo_df['targtype1_txt'], order = geo_df['targtype1_txt'].value_counts().index)
plt.ylabel('Target Type')
# Out:
# Text(0, 0.5, 'Target Type')

# %% [markdown]
# ### Conclusion : We can see Private Citizens & Property , Military and Police are the most frequent target of Attack.

# %% [markdown]
# # Geo-locations of Most Frequent Target of Terrorist Attack

# %%
df['targtype1_txt'].unique()
# Out:
# array(['Private Citizens & Property', 'Government (Diplomatic)',
#        'Journalists & Media', 'Police', 'Utilities', 'Military',
#        'Government (General)', 'Airports & Aircraft', 'Business',
#        'Educational Institution', 'Violent Political Party',
#        'Religious Figures/Institutions', 'Unknown', 'Transportation',
#        'Tourists', 'NGO', 'Telecommunication', 'Food or Water Supply',
#        'Terrorists/Non-State Militia', 'Other', 'Maritime',
#        'Abortion Related'], dtype=object)

# %%
country_map= gpd.read_file('World_Countries.shp')

fig,ax = plt.subplots(figsize=(20,20))
country_map.plot(ax=ax, alpha=0.5, color='grey')

geo_df[geo_df['targtype1_txt']=='Private Citizens & Property']['geometry'].plot(ax=ax, markersize=5,color='red',marker='o',label='Private Citizen & Property')

geo_df[geo_df['targtype1_txt']=='Military']['geometry'].plot(ax=ax, markersize=5,color='blue',marker='v',label='Military')

geo_df[geo_df['targtype1_txt']=='Police']['geometry'].plot(ax=ax, markersize=5,color='green',marker='^',label='Police')


plt.legend(prop={'size':20})

# %% [markdown]
# # Analyzing Suicide and Non-suicide Terrorist Attacks

# %%
geo_df['suicide'].value_counts().to_frame()
# Out:
#    suicide
# 0   175058
# 1     6633

# %% [markdown]
# #### We can see non-suicidal attacks are dominating compared to suicidal attacks. It is clear from the plot as well.

# %%
country_map= gpd.read_file('World_Countries.shp')

fig,ax = plt.subplots(figsize=(20,20))
country_map.plot(ax=ax, alpha=0.5, color='grey')

geo_df[geo_df['suicide']==1]['geometry'].plot(ax=ax, markersize=5,color='red',marker='o',label='Suicide Attack')


geo_df[geo_df['suicide']==0]['geometry'].sample(n=100000,random_state=0).plot(ax=ax, markersize=5,color='green',marker='^',label='Non-suicide Attack')


plt.legend(prop={'size':20})

# %% [markdown]
# # Most Active Terrorist Groups in the World

# %%
df[df['gname']!='Unknown']['gname'].value_counts().to_frame().head(20)
# Out:
#                                                   gname
# Taliban                                            7478
# Islamic State of Iraq and the Levant (ISIL)        5613
# Shining Path (SL)                                  4555
# Farabundo Marti National Liberation Front (FMLN)   3351
# Al-Shabaab                                         3288
# New People's Army (NPA)                            2772
# Irish Republican Army (IRA)                        2671
# Revolutionary Armed Forces of Colombia (FARC)      2487
# Boko Haram                                         2418
# Kurdistan Workers' Party (PKK)                     2310
# Basque Fatherland and Freedom (ETA)                2024
# Communist Party of India - Maoist (CPI-Maoist)     1878
# Maoists                                            1630
# Liberation Tigers of Tamil Eelam (LTTE)            1606
# National Liberation Army of Colombia (ELN)         1561
# Tehrik-i-Taliban Pakistan (TTP)                    1351
# ...

# %% [markdown]
# ### Conclusion : If we ignore the unknown groups, we get Taliban as the most active terrorist group followed by ISIL, SL and FMLN.

# %% [markdown]
# # Top 5 known Terrorist Attack groups and their active Region

# %%
country_map= gpd.read_file('World_Countries.shp')

fig,ax = plt.subplots(figsize=(20,20))
country_map.plot(ax=ax, alpha=0.5, color='grey')

geo_df[geo_df['gname']=='Taliban']['geometry'].plot(ax=ax, markersize=5,color='red',marker='o',label='Taliban')

geo_df[geo_df['gname']=='Islamic State of Iraq and the Levant (ISIL)']['geometry'].plot(ax=ax, markersize=5,color='blue',marker='^',label='ISIL')

geo_df[geo_df['gname']=='Shining Path (SL)']['geometry'].plot(ax=ax, markersize=5,color='green',marker='.',label='SL')

geo_df[geo_df['gname']=='Farabundo Marti National Liberation Front (FMLN)']['geometry'].plot(ax=ax, markersize=5,color='yellow',marker='s',label='FMLN')

geo_df[geo_df['gname']=='Al-Shabaab']['geometry'].plot(ax=ax, markersize=5,color='violet',marker='p',label='Al-Shabaab')




plt.legend(prop={'size':20})

# %% [markdown]
# # Most Used Primary Weapons used by Terrorists

# %%
df2 = df[df['weaptype1_txt']!='Unknown']

# %% [markdown]
# ### Conclusion : We can see Most used weapons used by Terrorists are Explosives followed by Firearms and Incendiary.

# %%
plt.figure(figsize=(15,15))
sns.countplot(y= df2['weaptype1_txt'],order=df2['weaptype1_txt'].value_counts().index )
# Out:
# <AxesSubplot:xlabel='count', ylabel='weaptype1_txt'>

# %% [markdown]
# # Terrorist Attack with Most No of Deaths

# %%
geo_df['nkill'].max()
# Out:
# 1570.0

# %%
geo_df[geo_df['nkill']==geo_df['nkill'].max()][['country_txt','city','targtype1_txt','target1','gname','weaptype1_txt','iyear']]
# Out:
#        country_txt    city targtype1_txt   target1  \
# 133518        Iraq  Tikrit      Military  Soldiers
#
#                                               gname weaptype1_txt  iyear
# 133518  Islamic State of Iraq and the Levant (ISIL)      Firearms   2014

# %% [markdown]
# ### Conclusion :
# We can see it happened in 1970 in the city `Tikrit` of `Iraq`.<br>
# No. of dead people : `1570` <br>
# Primary target : `Military(Soldiers)` .<br>
# Responsible terrorist group: `ISIL` .<br>
# Primary Weapon used : `Firearms`.<br>

# %% [markdown]
# # Terrorist Attack Success Rate

# %%
geo_df['success'].value_counts()
# Out:
# 1    161632
# 0     20059
# Name: success, dtype: int64

# %%
geo_df['success'].value_counts(normalize=True).plot(kind='barh')
plt.ylabel('Attack was sucessfull or Not')
plt.xlabel('Normalized Percenatage')
# Out:
# Text(0.5, 0, 'Normalized Percenatage')

# %% [markdown]
# ### Conclusions: We can see around 90% instances the attacks were successfull while others were not.

# %% [markdown]
# # Geo-locations where Terrorist attcks were successful and un-successful

# %%
country_map= gpd.read_file('World_Countries.shp')

fig,ax = plt.subplots(figsize=(20,20))
country_map.plot(ax=ax, alpha=0.5, color='grey')

geo_df[geo_df['success']==1]['geometry'].sample(n=100000,random_state=10).plot(ax=ax, markersize=5,color='red',marker='o',label='successful')

geo_df[geo_df['success']==0]['geometry'].plot(ax=ax, markersize=5,color='blue',marker='^',label='un-successful')

plt.legend(prop={'size':20})
